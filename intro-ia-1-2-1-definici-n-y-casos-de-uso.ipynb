# %% [markdown]
# <a href="https://www.kaggle.com/code/fizcogar/intro-ia-1-2-1-definici-n-y-casos-de-uso?scriptVersionId=118934270" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# **Inteligencia artificial. Definición y casos de uso (1 de 2)**
# ___

# %% [markdown]
# # Definición y clasificación
#
# ## Definición
# Es **difícil de definir**, teniendo en cuenta que no sabemos definir el término *'inteligencia'*
#
# Cualquier **proceso automático** que resuelva un problema que nos parece reservado, en principio, a **animales superiores**, es inteligencia artificial.
#
# ![dolphins-at-aquarium.jpg](attachment:dc64e541-a53f-4da9-90c8-b9dd5740d3d8.jpg)
#
# (Cuatro animales superiores. Dos de ellos se creen más superiores de lo que son).
#
#
# Conforme pasa el tiempo nos **acostumbramos** a los avances, y cosas que nos parecían inteligencia artificial **ya no nos lo parecen**.

# %% [markdown]
# ## Clasificación
#
# Hay muchas formas de clasificar casos de uso de IA. Por ejemplo:
# * Si se basa en el **entrenamiento** de un **modelo** a partir de un conjunto de datos o se basa en **programación 'tradicional'**
# * Si los datos para el entrenamiento incluyen el **objetivo** o no.
# * Si el objetivo es
#     * Predecir un valor contínuos (p.e. un precio)
#     * O una clasificación
#     * O algo más complejo
# * En función del **formato** de los datos de entrada (gráficos, lenguaje natural, datos tabulares ...)
# * En función de la **complejidad** de los problemas que se pueden resolver

# %% [markdown]
# # Casos de uso (1/2)
#
# Los pongo de dos en dos para poder compararlos y clasificarlos ...

# %% [markdown]
# ## Navegación para automóviles vs Predicción del precio del vino
#
# Los dos son **Inteligencia artificial**, pero:
# * Los navegadores funcionan con **programación tradicional**: el programador tiene que saber exactamente cómo se resuelve el problema y traducir ese conocimiento a un lenguaje de programación.
# * La predicción del vino es **aprendizaje máquina**: El sistema no se programa, se **entrena** para detectar patrones en un conjunto de datos.
#
# Hoy en día cuando se habla de IA, en general se está hablando de **Aprendizaje máquina** (Machine Learning, ML)
#
# ![wines.priced.jpg](attachment:84f6f9e2-ad48-4065-9d65-317af1723fe2.jpg) ![google-maps-navigation.jpg](attachment:242f68d5-2d9f-48b5-b844-3a4e7ce6634e.jpg)

# %% [markdown]
# ## Segmentación de clientes (clustering) vs Predicción del precio del vino
# Los dos son aprendizaje máquina, pero:
# * La predicción del precio del vino es **aprendizaje máquina supervisado**: los datos de entrenamiento incluyen la variable a predecir, en este caso el precio del vino.
# * La segmentación de clientes por 'clustering' es **aprendizaje máquina no supervisado**: los datos no incluyen una variable a predecir.
#
# El aprendizaje supervisado se adapta a muchos **más tipos de problemas** que el no supervisado, pero conseguir un buen conjunto de **datos de entrenamiento** es **trabajoso**, he implica muchas veces la participación de expertos de *negocio*.
#
# ![clustering-customer-segmentation.jpg](attachment:2ce43fc9-e004-432b-81cf-0247260295e9.jpg) ![wines.priced.jpg](attachment:5dda2ea7-babf-4551-83db-e25098e1eef1.jpg)
#
# (Imagen: [Customer-segmentation for differentiated targeting in marketing using clustering analysis](https://medium.com/analytics-vidhya/customer-segmentation-for-differentiated-targeting-in-marketing-using-clustering-analysis-3ed0b883c18b)

# %% [markdown]
# ## Guía para inspecciones sanitarias vs Predicción del precio del vino
#
# En ambos casos los datos son **tabulares**, e incluyen el **valor a predecir**:
# * En el primero, información recogida por los inspectores durante las inspecciones, incluyendo el resultado de la inspección
# * En el segundo, datos meteorológicos y los precios alcanzados por los vinos
# En ambos casos el valor a predecir es un valor contínuo, **un número**:
#   * En el primero, la probabilidad de que un restaurante vaya a cometer una infracción
#   * En el segundo, el precio que alcanzará el vino.
#
# En definitiva, son dos ejemplos de **regresión mediante aprendizaje máquina supervisado para datos tabulares**.
#
# ![restaurant.jpg](attachment:e963d282-468a-44bb-8823-895e57f33ccd.jpg) ![wines.priced.jpg](attachment:86718707-04cd-4c8a-82de-aa6f1bcbfe45.jpg)
#
# (Imagen: [Food Inspections in Chicago: EDA and Modeling](´)

# %% [markdown]
# ## Clasificación de retinografías vs Predicción del precio del vino
# Los dos son ejemplos de aprendizaje máquina, pero:
# * En cuanto al tipo de datos que **predice** el modelo
#   * La predicción del precio del vino en un problema de **regresión**: el resultado es un **valor contínuo** (un número, como el precio del vino).
#   * Este ejemplo de detección de  retinopatía es un problema de **clasificación**, el resultado es una **etiqueta**, la clase a la que pertenece la retinografía.
# * En cuanto a la **complejidad de los modelos** que se necesitan para resolver el problema:
#   * La predicción del precio del vino es **aprendizaje máquina**
#   * La clasificación de imágenes se considera **aprendizaje máquina profundo** o simplemente aprendizaje profundo (deep learning, DL)
#
# ![retina.jpg](attachment:5f20b89c-a0dc-4cd1-bccd-3c89dc89fa85.jpg) ![wines.priced.jpg](attachment:0855025d-1469-48d2-8b3d-297d65b2a28e.jpg)
#
# (Imagen: [kaggle - Diabetic Retinopathy Detection](![retina.jpg](attachment:84930c09-acf0-4e9f-b0ba-afea57a44176.jpg)))

# %% [markdown]
# ## Detección de piscinas en una fotografía satélite vs Predicción del precio del vino
# * Los dos son problemas de **regresión** (predicen números) pero la detección de objetos también **clasifica** los objetos encontrados.
# * Además, el tipo de datos de entrada es diferente
#   * En la predicción del precio del vino son datos **tabulares**
#   * En la detección de objetos, **imágenes**.
# * En cuanto a la **complejidad de los modelos** que se necesitan
#   * La predicción del precio del vino es **aprendizaje máquina**
#   * La detección de objetos se considera **aprendizaje profundo**
#
# ![yolo-pools.png](attachment:57c77b15-0589-43c1-9bac-34eff67a87a3.png)  ![wines.priced.jpg](attachment:88c63797-33ae-48a9-b295-5b9bf7ccfae3.jpg)
#
# (Imagen: [Swimming pool detection and classification using deep learning](https://medium.com/geoai/swimming-pool-detection-and-classification-using-deep-learning-aaf4a3a5e652))
