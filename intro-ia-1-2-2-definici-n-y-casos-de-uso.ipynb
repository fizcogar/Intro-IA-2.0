# %% [markdown]
# <a href="https://www.kaggle.com/code/fizcogar/intro-ia-1-2-2-definici-n-y-casos-de-uso?scriptVersionId=118934900" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
# **Inteligencia artificial. Definición y casos de uso (2 de 2)**
#
# ---

# %% [markdown]
# # Casos de uso (2 de 2)

# %% [markdown]
# ## Reconocimiento de entidades en textos vs Clasificación de retinografías
# * En cuanto a la complejidad de los modelos, los dos son problemas de **aprendizaje profundo**
# * En cuanto a los datos de entrada, el 'Reconocimiento de Entidades Nombradas' es **procesado de lenguaje natural (NLP)**
#
# ![ner.jpg](attachment:669ae0bd-9e22-4e0f-b9d6-d2857eaba70a.jpg)
# ![retina.jpg](attachment:68cc9df6-5beb-40c0-b1ad-b6f53edfdab4.jpg)
#
# (Imagen: [8 lessons learned about NER](https://medium.com/dpa-newslab/8-lessons-learned-about-ner-f40b263490db))

# %% [markdown]
# ## Segmentación de imagen médica vs Clasificación de retinografías
# Los dos son ejemplos de **aprendizaje supervisado profundo** pero:
# * En el caso de las retinografías el objetivo es **clasificarlas** según la gravedad de la retinopatía detectada.
# * Curiosamente, la **segmentación de imágenes** es también un problema de clasificación, pero **llevado al extremo**: clasifica cada pixel de una imagen.
#
# ![medical-segmentation.jpeg](attachment:6fc0abb0-3e0b-43ad-937c-6cf9c6fa7856.jpeg) ![retina.jpg](attachment:96b153cb-7bb8-479a-a7a4-d48323e7d407.jpg)
#
# (Imagen: [CT Segmentation in orthopedic surgery](https://www.rsipvision.com/ct-segmentation-orthopedic-surgery/))

# %% [markdown]
# ## Otros casos de uso

# %% [markdown]
# ## **Deep Blue** (IBM, 1996) vs **Alphazero** (Google, 2017)
# * Deep blue era un modelo de **programación tradicional**: Aprovechaba la 'fuerza bruta' en **búsquedas en árbol** y reglas programadas por expertos  ajedrecistas (**heurística**)
# * Alphazero es **aprendizaje reforzado**, un tipo de aprendizaje máquina aplicable a universos cerrados, como los juegos. Ademas, dada la complejidad del problema, es **aprendizaje profundo**
#
# ![DeepBlue.jpg](attachment:1c1ba86a-3175-4be0-a2ef-bd6dd60acdb6.jpg)![alphazero-carlsen.jpg](attachment:1390bcd9-2f0e-4278-9831-6211d5131445.jpg)

# %% [markdown]
# ## 'This person does not exist' (Nvidia, 2018) vs Stable Difussion (2022)
# Ambos son **modelos generativos**, un caso particular de **aprendizaje profundo**.
# * En ['This person does not exist'](https://thispersondoesnotexist.com/) la entrada del modelo es ruido blanco, y la salida una imagen digital
# * En [Stable Difussion](https://stablediffusionweb.com/) la entrada es **un texto** ("Una fotografía de un astronauta  montando a caballo"),  y la salida una imagen digital.
#
# ![notexist.jpg](attachment:3e894a8f-d79b-4cc4-9f40-9e3128e45280.jpg) ![stable-difussion-3.jpg](attachment:873bab61-ec4a-42fe-b9d2-cf2fbb394c32.jpg)

# %% [markdown]
# ## ChatGPT vs 'This person does not exist'
# Nos lo explica el propio ChtGPT:
#
# ![chatgpt.jpg](attachment:e96d9791-de13-4dd0-86d9-fdbbc8e9f4d5.jpg)  ![notexist.jpg](attachment:b92dc2f1-5961-4306-8fcb-9b52d3dd6652.jpg)
