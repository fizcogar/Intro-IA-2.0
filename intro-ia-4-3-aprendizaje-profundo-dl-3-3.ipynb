# %% [markdown]
# <a href="https://www.kaggle.com/code/fizcogar/intro-ia-4-3-aprendizaje-profundo-dl-3-3?scriptVersionId=115878178" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introducción a la Inteligencia Artificial
# ## Aprendizaje Profundo (3/3)

# %% [markdown]
# # Servicios de computación para aprendizaje profundo. Unidades de proceso gráfico (Graphics processing unit, GPUs)
#
# Los ordenadores apropiados para el entrenamiento de modelos de aprendizaje profundo son **herramientas especializadas**, dotadas de potentes GPUs (unidades de proceso gráfico).
#
# Se llaman así porque nacieron por el **auge de los videojuegos**. Pero coincide que manejar los **gráficos tridimensionales de un videojuego** y el **aprendizaje profundo** implican lo mismo: **sumas y multiplicciones de vectores y matrices**.
#
# Muchas veces resulta más económico **alquilar** computación en la nube y **pagar por** uso que adquirir sistemas especializados para aprendizaje máquina. Aquí una **lista de precios** (obsoleta) del uso de GPUs del servicio Microsoft Azure:
#
# ![azure.nc6.jpg](attachment:8f6a348a-c7bb-42aa-a502-3d9f35e5b26a.jpg)

# %% [markdown]
# # Librerías de aprendizaje profundo
#
# Al igual que para aprendizaje máquina, tenemos magníficas librerías 'open source' para aprendizaje profundo.
# * Algunas son de **alto nivel de abstracción**, como fastai, Keras o Huggingface: lmás fáciles de usar pero menos flexibles.
# * Otras son de más **bajo nivel de abstracción**: mayor curva de aprendizaje, pero más flexibles.
#
# A menudo las primeras están basadas en las segundas.
#
# ![libs-dl.jpg](attachment:40e8c775-20f8-4d25-8bf1-7163aff181d9.jpg)
#
# # Datasets para entrenamiento
#
# Para aprovechar la transferencia de aprendizaje hay muchos proyectos que recopilan y publican excelentes **conjuntos de datos** para preentrenar modelos de DL.
# * Algunos de propósito general, como **imagenet**
# * Otros dedicados a un ámbito concreto
#
# ![imagenet.jpg](attachment:b24c7559-f76c-4fbf-a023-a78e18820036.jpg)
#
# # Modelos preentrenados
#
# Finalmente, también contamos con modelos ya preentrenados con los **datasets** antes mencionados, principalmente para:
# * Procesado de **Imagen Digital**
# * Procesado de **Lenguaje Natural**
#
# Cada **librería** de DL suele proporcionar sus propias implementaciones de estos modelos preentrenados.
#
# En cuanto al **coste**:
# * Algunos son de libre acceso, como los de:
#   * [TensorFlow Hub](https://www.tensorflow.org/hub)
#   * [Keras](https://keras.io/api/applications/)
#   * [PyTorch Hub](https://pytorch.org/hub/)
#   * [Huggingface](https://huggingface.co/models)
#   * [Gluon Zoo (mxnet)](https://mxnet.apache.org/api/python/docs/api/gluon/model_zoo/index.html)
# * De pago como servicio, como [OpenAI](https://openai.com/api/)

# %% [markdown]
# # Claves

# %% [markdown]
# ## Aprendizaje Profundo = Modelos avanzados + Datos + Potencia de cálculo
# * Los modelos de DL son redes neuronales que puede aprovechar **grandes cantidades de datos** ...
# * ... siempre que tengamos suficiente **potencia de cálculo** para entrenar el modelo.
#
# ![nn.jpg](attachment:81a0f915-19da-4288-ae8a-0e374bb8e9fd.jpg)![dl.vs.ml.jpg](attachment:ffff4e65-3007-4a2d-9a9d-9aa650e936ed.jpg)

# %% [markdown]
# ## Rendimiento y tamaño de una red neuronal
#
# * Aunque en principio una NN lo bastante grande puede resolver cualquier problema 'computable', el rendimiento de una NN **raramente es mejor que el de un experto humano**
# * Los modelos de DL se entrenan para resolver un problema concreto. **No existe** una Inteligencia Artificial **universal**
# * Los modelos de mejor rendimiento son **muy grandes** (miles de millones de parámetros) y son **muy costosos de entrenar**

# %% [markdown]
# ## Transferencia de aprendizaje
#
# * Podemos aprovechar un **modelo preentrenado**, reentrenando sólo las últimas capas **('fine tuning')** para la finalidad que buscamos, ahorrando mucho tiempo y dinero!
#
# ![transferencia.jpg](attachment:a14e402d-40f3-476a-8418-c4870ae7245e.jpg)

# %% [markdown]
# ## Pago por uso de GPUs
#
# En lugar de adquiririr costosos ordenadores especializados (con potentes GPUs), muchas veces es más económico el **pago por uso** de servicios de computación **en la nube**.

# %% [markdown]
# ## Datasets, librerías y modelos preentrenados
#
# Disponemos de:
# * **Datasets** de muy buena calidad y libre acceso
# * **Librerías**, muchas de ellas 'open source'
# * **Modelos preentrenados**
#
# Que facilitan el entrenamiento de modelos de aprendizaje profundo con un **coste razonable.**
#
# ![libs-dl.jpg](attachment:946706cd-2da6-43d8-a0bc-4d857c231d2f.jpg)
