# %% [markdown]
# <a href="https://www.kaggle.com/code/fizcogar/intro-ia-5-nlp-3?scriptVersionId=115886658" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introducción a la Inteligencia Artificial
# ## Aprendizaje Profundo
# ### Procesamiento de Lenguaje Natural (NLP)

# %% [markdown]
# # Transferencia de aprendizaje a partir de un modelo 'como servicio' (OpenAI GPT-3)
#
#
# **'Generative Pre-trained Transformer 3'**, conocida por sus siglas (GPT-3), es un modelo de lenguaje autorregresivo que emplea aprendizaje profundo para producir textos que simulan la redacción humana. Es la tercera generación de los modelos de predicción de lenguaje perteneciente a la serie GPT, creados por OpenAI, un laboratorio de investigación de inteligencia artificial con sede en San Francisco.1 La versión completa de GPT-3 tiene una capacidad de **175.000 millones de parámetros** de aprendizaje automatizado.
#
# https://es.wikipedia.org/wiki/GPT-3
#
# **ChatGPT** es una especialización de GPT3 orientado a la conversación.
#
# https://chat.openai.com/chat

# %% [markdown]
# ## Reentranamiento (fine tuning)
# ### Formato del conjunto de datos de reentrenamiento
#
# ```json
# {"prompt" : "¿Qué es el Modelo DGTD? -->", "completion" : "En la DGTD se ha ido concretando a lo largo del tiempo un modelo de trabajo, que ayuda y guía a los técnicos y responsables de la DGTD a trabajar de cara a dar el mejor servicio. El modelo ordena las tareas y relaciones entre los diferentes roles a alto nivel, lo que lo hace flexible para adaptarse a las necesidades concretas de cada unidad de la DGTD y de cada cliente. La DGTD tiene la competencia exclusiva de las TIC en Gobierno de Navarra. El modelo de la DGTD concreta la forma de trabajo de todas las partes para alcanzar las necesidades de cada departamento de Gobierno de Navarra en materia TIC. Los clientes piden a la DGTD la creación y mantenimiento de productos TIC o productos que en alguna de sus partes disponen de TIC. Las personas de la DGTD durante el ciclo de vida de un producto realizan diferentes procesos de alto nivel alrededor de los mismos, estos serían estudiar y decidir, crear y evolucionar, operar y soportar. A lo largo de todos los procesos, las personas de la DGTD y del cliente, juegan unos roles que determinan sus responsabilidades."}
#
# {"prompt" : "Según el Modelo DGTD ¿Qué es un producto? -->", "completion" : "Se entienden como productos los sistemas TIC utilizados en Gobierno de Navarra que son creados y/o mantenidos por la DGTD. También se consideran productos las distintas infraestructuras y plataformas sobre las que estos sistemas de información están implantados."}
#
# {"prompt" : "Según el Modelo DGTD ¿Cuáles son los servicios? -->", "completion" : "Un servicio es un conjunto de acciones que satisfacen una necesidad que no consiste en la creación o evolución de un producto, por ejemplo, soporte, operación, consultoría, auditoría, gestión de cuenta, etc. Un servicio se caracteriza por ser permanente: continúa prestándose hasta que se decide la discontinuidad del mismo"}
#
# {"prompt" : "Según el Modelo DGTD ¿Quiénes son los clientes? -->", "completion" : "Las unidades de Gobierno de Navarra que paga por los servicios y productos TIC de la DGTD."}
# ```

# %% [markdown]
# ### Creación del nuevo modelo
#
# OpenAI ofrece un **servicio** en la nube para la creación de modelos a medida. El proceso de reentramiento se ejecuta en sus máquinas, y tiene un coste.
#
# `openai -k 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 api fine_tunes.create -t "Modelo_DGIT_0-1_prepared.json" -m davinci`

# %% [markdown]
# ### Uso del nuevo modelo
#
# **No se puede descargar el modelo** para inferencia, para integrarlo en un sistema de información tienes que llamar a la API de OpenAI.
#
# Cada llamada tiene un coste, aunque mucho menor que el coste del entrenamiento.
#
# También se puede probar en la **OpenAI Playground**
#
# ![gpt3-diálogo.jpg](attachment:18d4e511-aba8-45be-aa75-5336c2083d0f.jpg)
#
# https://beta.openai.com/playground

# %% [markdown]
# ### Temperatura
#
# El modelo reentrenado puede ser más aleatorio modificando la 'temperatura'. Con una temperatura alta sus respuestas son ... 'imaginativas'.
#
# `Pregúntame:Según el modelo de la DGTD ¿En quién puede delegar el referente del departamento?--> En el Responsable de Servicio de Desarrollo Técnico (RCsT)`
#
# La respuesta parece convincente, pero **es una invención**. En nuestro modelo de trabajo no existe el rol de 'Responsable de Servicio de Desarrollo Técnico', pero ChatGPT incluso se inventa una sigla **(RCsT)** similar a las que usamos en nuestra 'jerga' particular.

# %% [markdown]
# ### Coste del servicio
#
# Por entrenamiento y por uso. Actualmente te conceden un crédito de 18 dólares al dar de alta una cuenta en OpenAI.
#
# El coste del 9 de diciembre corresponde principalmente al entrenamiento del modelo. El del 10, a diferentes pruebas de inferencia en el **OpenAI Playground**.
#
# ![gpt3-coste.png](attachment:d3066049-3a7b-4549-9135-401873c22299.png)
