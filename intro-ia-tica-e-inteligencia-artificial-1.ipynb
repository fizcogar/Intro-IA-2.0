# %% [markdown]
# <a href="https://www.kaggle.com/code/fizcogar/intro-ia-tica-e-inteligencia-artificial-1?scriptVersionId=115890974" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introducción a la Inteligencia Artificial
# ## Ética e Inteligencia Artificial (1/2)

# %% [markdown]
# # Un vídeo para empezar
# **Bill Hader**, el mejor actor del mundo: es capaz de cambiar su rostro para parecerse a Tom Cruise ...

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VWrhRBb-1Ig')

# %% [markdown]
# # ¿Alarmismo ante una nueva tecnología?
#
# ![accidente.jpg](attachment:692619cd-ae45-4566-a1e3-23ba1b1807f2.jpg)
#
# En los albores de la automoción, las primeras voces que alertaban de la necesidad de diseñar los automóviles pensando en la seguridad de los pasajeros eran tenidas por **alarmistas**, sobre todo por parte de **los fabricantes de automóviles**.
#
# Lo mismo pensaba yo las primeras veces que escuché que la IA podía presentar importantes problemas éticos. Pues bien, **no es alarmismo, está ocurriendo**.

# %% [markdown]
# # La AI está magnificando el sesgo humano
#
# ## ¿Cómo aprendemos nosotros?
#
# ![profesiones.1.jpg](attachment:907b5baf-8b20-45f9-a4a0-2a2accc4fd64.jpg)
#
# Una de las **similitudes** entre la inteligencia artificial y la inteligencia natural es que, en algunos casos, las inteligencias artificiales aprenden de forma parecida a como aprendemos los animales: **aprenden con ejemplos**.
#
# Imaginad a un grupo de chiquillos que están en el cole aprendiendo las profesiones. La profesora les enseña un dibujo de un señor con bata y estetoscopio y algunos niños gritan **¡Médico!** Una señora ante una pizarra **¡Maestra!** Y así, sucesivamente.
#
# La memoria de los niños **no es fotográfica**, no recuerdan cada detalle de cada dibujo, lo que su mente aprende es **un patrón**, la esencia que diferencia el dibujo de una profesión de otro, por eso son capaces de reconocer una profesión en un dibujo que no han visto antes.

# %% [markdown]
# ![profesiones.3.jpg](attachment:4e56c86c-3987-4c44-a1f9-48c5632235ec.jpg)
#
# Si los ejemplos con los que aprenden los niños están sesgados, van a aprender un **patrón incorrecto**. Por ejemplo, si en los dibujos **los médicos  son hombres y las enfermeras mujeres**, el patrón será incorrecto, sesgado, y, además **discriminatorio**.

# %% [markdown]
# ## ¿Cómo aprenden las máquinas?
#
# ![yolo2.jpg](attachment:1dd2148f-a802-4798-aa59-ec34e9dcefda.jpg)
#
# Los sistemas más populares de Inteligencia Artificial aprenden de manera similar: a partir de un conjunto de ejemplos son capaces de aprender a reconocer **patrones**, y distinguir, por ejemplo, coches, motocicletas, peatones, bicicletas, a partir de imágenes de ejemplo proporcionadas durante el entrenamiento. Si entre los ejemplos **faltan imágenes de un tipo concreto de vehículo, por ejemplo, motocicletas**, el patrón aprendido será incorrecto y el sistema confundirá, probablemente, bicicletas con motocicletas.
#
# Por supuesto, si un sistema de Inteligencia Artificial se emplea en el ámbito de las relaciones humanas, **un patrón sesgado puede llevar a la discriminación**.

# %% [markdown]
# ![amazon.false.matches.jpg](attachment:95107351-8fd2-414d-b0e8-9a11b157bbf3.jpg)
#
# En 2018,  La Unión Estadounidense por las Libertades Civiles (UCLA) demostró que el sistema **‘Rekognition’**, del gigante norteamericano **Amazon**, usado por varios departamentos norteamericanos de **policía**, identificó como criminales a **28 congresistas, la mayoría negros o latinos**.
#
# ¡Y no lo eran!

# %% [markdown]
# ![bias.facial.jpg](attachment:fe0cd7e5-d919-4d37-908e-9eb3fed88960.jpg)
#
# De hecho, investigadores del Instituto de Tecnología de Massachusetts demostraron que tanto Rekognition como **sistemas similares de IBM y Microsoft** funcionaban mucho mejor reconociendo a **hombres blancos** que a **mujeres negras**.

# %% [markdown]
# ![google.sesgo.jpg](attachment:407e2dac-f0f2-4e17-a9d1-52ebdb0473a1.jpg)
#
# Otro gigante, Google, tampoco se libra. En idioma turco los términos doctor y enfermera son neutros, no tienen género. Pues bien, en el traductor de Google, si traducías al turco la frase ‘she is a doctor, he is a nurse’ (ella es doctor, el es enfermero) y volvías a traducir del turco al ingles, el resultado era, como no, ‘he is a doctor, she is a nurse’ (el es doctor, ella es enfermera). No intentes reproducirlo, afortunadamente ya lo han corregido

# %% [markdown]
# ## ¿Por qué está pasando?
#
# Estos dos ejemplos son sistemas mal entrenados porque seguramente **los datos de entrenamiento** estaban sesgados. En el caso del reconocimiento facial, seguramente había mas imágenes de ejemplo de **hombres blancos que de mujeres negras**. En el caso del traductor de Google, estos sistemas se entrenan con grandes conjuntos de texto, como por ejemplo la Wikipedia. Si el **texto original tiene sesgo**, el sistema lo incorpora.

# %% [markdown]
# Esto se puede ver con facilidad en los **modelos preentrenados**. Por ejemplo, el modelo de NLP que hemos visto antes estaba preentrenado primero con la Wikipedia en inglés y afinado después con la Wikipedia en castellano. Si la Wikipedia tiene sesgos, el modelo los hereda:
#
# ![sesgo-modelos-NLP-1.jpg](attachment:c972365c-bb5c-4fd8-bbe4-9dabd97965db.jpg)

# %% [markdown]
# El sesgo no es especialmente 'maligno', simplemente ha sido entrenado con textos que contienen muchas veces la expresión 'raza negra':
#
# ![sesgo-modelos-NLP-2.jpg](attachment:776025f8-4b7c-4947-b2e9-50f1c92776ac.jpg)

# %% [markdown]
# Un modelo sesgado **puede ser de utilidad**, siempre que seamos conscientes del sesgo. Pero parece **incomprensible** que compañías de tal prestigio puedan poner en producción sistemas tan sesgados. ¿Es, en realidad, un problema técnico? Sí, pero no detectarlo a tiempo no es un problema técnico. ¿Por qué ocurre?
#
# **Tal vez porque el entorno de investigación y desarrollo de IA es muy exclusivo. Por ejemplo, sólo el 12% son mujeres.**
